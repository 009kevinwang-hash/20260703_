# %%
print('this is number one')
print("this is 2")
print('line 3')
# Out:
# this is number one
# this is 2
# line 3

# %% [markdown]
# # head1
# ## head2
# ### head3
# #### head4
# ##### head5
# ###### head6

# %%
n = 5
m = 6
total = n+m
total
# Out:
# 11
