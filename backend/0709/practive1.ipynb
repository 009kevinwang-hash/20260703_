# %%
print("Hello World")
# Out:
# Hello World

# %%
import math

a:int = 3
b:int = 4
value1:float = math.pow(a,2) + math.pow(b,2)
value2:float = math.sqrt(value1)
print(value2)
# Out:
# 5.0

# %%
[
    {'name':"robert",'age':30},
    {'name':"222",'age':31},
    {'name':"3333",'age':33}
]
# Out:
# [{'name': 'robert', 'age': 30},
#  {'name': '222', 'age': 31},
#  {'name': '3333', 'age': 33}]
